# %%
import pandas
import numpy

import requests
import json

from pprint import pprint


# import urlib.request

# from urllib import parse
# import pandas as pd
# from bs4 import BeautifulSoup
# from datetime import datetime

# %%
url = ' http://apis.data.go.kr/B190017/GetFnncCmpnyFundSpprDtflService/getFnncCmpnyFundSpprDtfl'
params={'serviceKey':'+D+bQDvFT8ereI8k58IHSCK0+EpeBRyno5+NQrTSiZujJLljyd9/C/hCDQccjOYnAnDBqvb3HI4T3jP4dIemIw==',
        # 'numOfRows': 10,
        'resultType':'json',
        'baseYm' : '201906'
}

resp=requests.get(url, params)
print(resp.content)
# Out:
# b'{"getFnncCmpnyFundSpprDtfl":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE"},"item":[{"rpymFndSpprAstByngAmt":"0","spraccSpprEpamt":"0","spprFnccmpRsluMthoNm":"\xec\xb2\xad\xed\x8c\x8c\xec\x82\xb0","fncIstNm":"\xed\x95\x9c\xeb\xa6\xbc","spraccSpprIbamt":"0","spraccSpprFncgAmt":"0","spraccFnamtRtrvAmt":"0","rpymFndSpprSscrAmt":"0","spraccLnRtrvAmt":"0","baseYm":"201906","spraccSpprSscrAmt":"0","spraccRtrvSumAmt":"0","rpymFndRtrvAstDspslAmt":"0","rpymFndSpprStotAmt":"294","bzrgtClsfNm":"\xec\x8b\xa0\xed\x98\x91","rpymFndRtrvLnAmt":"0","spprFnccmpNm":"\xed\x95\x9c\xeb\xa6\xbc","spraccSpprSumAmt":"0","spraccBkrpDvdnRtrvAmt":"0","spraccSpprKrncLnAmt":"0","rpymFndSpprFncgAmt":"0","rpymFndRtrvStotAmt":"262","rpymFndSpprLnAmt":"0","num":"1","rpymFndRtrvFncgAmt":"0","spraccRtrvEtcAmt":"0","rpymFndRtrvBkrpDvdnAmt":"262","rpymFndSpprDpsmPrxpayAmt":"294"},{"rpymFndSpprAstByngAmt":"0","spraccSpprEpamt":"0","spprFnccmpRsluMthoNm":"\xec\xb2\xad\xed\x8c\x8c\xec\x82\xb0","fncIstNm":"\xed\
# ...

# %%
resp.text
# Out:
# '{"getFnncCmpnyFundSpprDtfl":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE"},"item":[{"rpymFndSpprAstByngAmt":"0","spraccSpprEpamt":"0","spprFnccmpRsluMthoNm":"청파산","fncIstNm":"한림","spraccSpprIbamt":"0","spraccSpprFncgAmt":"0","spraccFnamtRtrvAmt":"0","rpymFndSpprSscrAmt":"0","spraccLnRtrvAmt":"0","baseYm":"201906","spraccSpprSscrAmt":"0","spraccRtrvSumAmt":"0","rpymFndRtrvAstDspslAmt":"0","rpymFndSpprStotAmt":"294","bzrgtClsfNm":"신협","rpymFndRtrvLnAmt":"0","spprFnccmpNm":"한림","spraccSpprSumAmt":"0","spraccBkrpDvdnRtrvAmt":"0","spraccSpprKrncLnAmt":"0","rpymFndSpprFncgAmt":"0","rpymFndRtrvStotAmt":"262","rpymFndSpprLnAmt":"0","num":"1","rpymFndRtrvFncgAmt":"0","spraccRtrvEtcAmt":"0","rpymFndRtrvBkrpDvdnAmt":"262","rpymFndSpprDpsmPrxpayAmt":"294"},{"rpymFndSpprAstByngAmt":"0","spraccSpprEpamt":"0","spprFnccmpRsluMthoNm":"청파산","fncIstNm":"한새","spraccSpprIbamt":"0","spraccSpprFncgAmt":"0","spraccFnamtRtrvAmt":"0","rpymFndSpprSscrAmt":"0","spraccLnRtrvAmt":"0","baseYm":"201906
# ...

# %%
resp.json()
# Out:
# {'getFnncCmpnyFundSpprDtfl': {'header': {'resultCode': '00',
#    'resultMsg': 'NORMAL SERVICE'},
#   'item': [],
#   'rows': None,
#   'numOfRows': 10,
#   'pageNo': 1,
#   'totalCount': 0}}

# %%
json.loads(resp.text)
# Out:
# {'getFnncCmpnyFundSpprDtfl': {'header': {'resultCode': '00',
#    'resultMsg': 'NORMAL SERVICE'},
#   'item': [],
#   'rows': None,
#   'numOfRows': 10,
#   'pageNo': 1,
#   'totalCount': 0}}

# %%
pprint(json.loads(resp.text))
# Out:
# {'getFnncCmpnyFundSpprDtfl': {'header': {'resultCode': '00',
#                                          'resultMsg': 'NORMAL SERVICE'},
#                               'item': [{'baseYm': '201912',
#                                         'bzrgtClsfNm': '저축은행',
#                                         'fncIstNm': '우리금융지주',
#                                         'num': '1',
#                                         'rpymFndRtrvAstDspslAmt': '0',
#                                         'rpymFndRtrvBkrpDvdnAmt': '0',
#                                         'rpymFndRtrvFncgAmt': '0',
#                                         'rpymFndRtrvLnAmt': '0',
#                                         'rpymFndRtrvStotAmt': '0',
#                                         'rpymFndSpprAstByngAmt': '0',
#                                         'rpymFndSpprDpsmPrxpayAmt': '0',
#                                         'rpymFndSpprFncgAmt': '0',
# ...

# %%
url='https://open.assembly.go.kr/portal/openapi/TVBPMBILL11'
params={'Type':'json',
        'pIndex':'1',
        'pSize':'5',
       'RROPOSER_KIND':'정부'
       }
resp=requests.get(url, params)
print(resp.content)
resp.text
# Out:
# b'{"TVBPMBILL11":[{"head":[{"list_total_count":88687},{"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4."}}]},{"row":[{"BILL_ID":"016163","BILL_NO":"160052","AGE":"16","BILL_NAME":"\xea\xb8\xb0\xec\x97\x85\xea\xb5\xac\xec\xa1\xb0\xec\xa1\xb0\xec\xa0\x95\xed\x88\xac\xec\x9e\x90\xed\x9a\x8c\xec\x82\xac\xec\x97\x90\xea\xb4\x80\xed\x95\x9c\xeb\xb2\x95\xeb\xa5\xa0\xec\x95\x88","PROPOSER":"\xec\xa0\x95\xeb\xb6\x80","PROPOSER_KIND":"\xec\xa0\x95\xeb\xb6\x80","PROPOSE_DT":"2000-06-30","CURR_COMMITTEE_ID":"9700009","CURR_COMMITTEE":"\xec\x9e\xac\xec\xa0\x95\xea\xb2\xbd\xec\xa0\x9c\xec\x9c\x84\xec\x9b\x90\xed\x9a\x8c","COMMITTEE_DT":"2000-07-03","COMMITTEE_PROC_DT":null,"LINK_URL":"https://likms.assembly.go.kr/bill/billDetail.do?billId=016163","PROC_RESULT_CD":"\xec\x88\x98\xec\xa0\x95\xea\xb0\x80\xea\xb2\xb0","PROC_DT":"2000-10-09"},{"BILL_ID":"016164","BILL_NO":"160053","AGE":"16","BILL_NAME":
# ...

# %%
pprint(resp.text)
# Out:
# ('{"TVBPMBILL11":[{"head":[{"list_total_count":88687},{"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 '
#  '처리되었습니다."}}]},{"row":[{"BILL_ID":"016163","BILL_NO":"160052","AGE":"16","BILL_NAME":"기업구조조정투자회사에관한법률안","PROPOSER":"정부","PROPOSER_KIND":"정부","PROPOSE_DT":"2000-06-30","CURR_COMMITTEE_ID":"9700009","CURR_COMMITTEE":"재정경제위원회","COMMITTEE_DT":"2000-07-03","COMMITTEE_PROC_DT":null,"LINK_URL":"https://likms.assembly.go.kr/bill/billDetail.do?billId=016163","PROC_RESULT_CD":"수정가결","PROC_DT":"2000-10-09"},{"BILL_ID":"016164","BILL_NO":"160053","AGE":"16","BILL_NAME":"금융지주회사법안","PROPOSER":"정부","PROPOSER_KIND":"정부","PROPOSE_DT":"2000-06-30","CURR_COMMITTEE_ID":"9700009","CURR_COMMITTEE":"재정경제위원회","COMMITTEE_DT":"2000-07-03","COMMITTEE_PROC_DT":null,"LINK_URL":"https://likms.assembly.go.kr/bill/billDetail.do?billId=016164","PROC_RESULT_CD":"수정가결","PROC_DT":"2000-10-09"},{"BILL_ID":"016165","BILL_NO":"160048","AGE":"16","BILL_NAME":"송아지생산안정에관한법률안","PROPOSER":"이강두의원등 '
# ...

# %%
url='https://open.assembly.go.kr/portal/openapi/RESREPORT'
params={'Type': 'json'}
resp=requests.get(url, params)
resp.json()
# Out:
# {'RESREPORT': [{'head': [{'list_total_count': 75},
#     {'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'}}]},
#   {'row': [{'TITLE': '[연구자료] Teaching about the Future',
#      'CHIEF_RESRCH': '국회미래연구원',
#      'REG_DTTM': '2018-07-14',
#      'DETAIL_URL': 'https://www.nafi.re.kr/new/research.do?mode=view&articleNo=161&article.offset=70&articleLimit=10'},
#     {'TITLE': '[연구자료] Global Europe 2050',
#      'CHIEF_RESRCH': '김홍범',
#      'REG_DTTM': '2018-07-25',
#      'DETAIL_URL': 'https://nafi.re.kr/new/research.do?mode=view&articleNo=2461&article.offset=0&articleLimit=10&srSearchVal=Global+Europe'},
#     {'TITLE': '[위탁연구] "미래 영향 환경변수 및 시나리오 도출 연구" 기술자문 결과보고서',
#      'CHIEF_RESRCH': 'KISTI 미래기술분석센터 박진서, 이준영',
#      'REG_DTTM': '2018-11-01',
#      'DETAIL_URL': 'https://nafi.re.kr/new/research.do?mode=view&articleNo=2462&article.offset=70&articleLimit=10'},
#     {'TITLE': '[연구자료] 한반도의 미래 공론조사 자료집',
#      'CHIEF_RESRCH': '이채정',
#      'REG_DTTM': '2018-11-29',
# ...

# %%
# params={'ServiceKey': '+D+bQDvFT8ereI8k58IHSCK0+EpeBRyno5+NQrTSiZujJLljyd9/C/hCDQccjOYnAnDBqvb3HI4T3jP4dIemIw==',
#        'pageNo':1}
# resp=requests.get(url, params)
# resp.json()

url = 'http://apis.data.go.kr/9760000/PartyPlcInfoInqireService/getPartyPlcInfoInqire'
key = '+D+bQDvFT8ereI8k58IHSCK0+EpeBRyno5+NQrTSiZujJLljyd9/C/hCDQccjOYnAnDBqvb3HI4T3jP4dIemIw=='
params ={'serviceKey' : key, 'pageNo' : '1', 'numOfRows' : '10','resultType':'json', 'sgId' : '20170509', 'partyName' : '더불어민주당'
        }

response = requests.get(url, params=params)
# print(response.content)

# %%
pprint(response.json())
# Out:
# {'getPartyPlcInfoInqire': {'header': {'code': 'INFO-00',
#                                       'message': 'NORMAL SERVICE'},
#                            'item': [{'num': '1',
#                                      'partyName': '더불어민주당',
#                                      'prmmCont1': '일자리 확대, 국민께 드리는 최고의 선물입니다\n'
#                                                   '\n'
#                                                   '□ 목 표 \n'
#                                                   ' ○ 삶의 질을 향상시키는 공공·사회 서비스 '
#                                                   '일자리 창출\n'
#                                                   ' ○ 혁신적 4차 산업 경제 생태계 구축으로 좋은 '
#                                                   '일자리 창출\n'
#                                                   ' ○ 스타트업·벤처 창업하기 좋은 기업 생태 환경 '
#                                                   '조성 \n'
#                                                   ' ○ 노동시간 단축으로 일·삶·가정 양립 및 '
# ...
